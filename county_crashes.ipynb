# %% [markdown]
# ## 1.3.3 Drill: Present the same data multiple ways
#
# Dataset of choice:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

crash_data = pd.read_csv('reordered2016crashes.csv')

# raw dataset sample
crash_data.head()
# Out:
#     CRASH_CRN  DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  CRASH_YEAR  \
# 0  2016016958        11             2          2301        2301        2016
# 1  2016017490        11             2          2301        2301        2016
# 2  2016047300        11             2          2121       68D02        2016
# 3  2016048852        11             2          2301        2301        2016
# 4  2016052699        11             2          2301        2301        2016
#
#    CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  HOUR_OF_DAY          ...            \
# 0            2            6         1255           12          ...
# 1            2            7         1752           17          ...
# 2            4            2         2321           23          ...
# 3            5            6         2340           23          ...
# 4            5            1         1450           14          ...
#
#    ACCESS_CTRL  ROADWAY_COUNTY  LANE_COUNT  RDWY_ORIENT  ROAD_OWNER  ROUTE  \
# ...

# %% [markdown]
# ## One Variable Plots: Number of Crashes

# %%
# graphing the number of crashes each month four different ways
monthly_crashes = crash_data.groupby(['CRASH_MONTH']).count()
p = sns.barplot(x=monthly_crashes.index, y=monthly_crashes['CRASH_CRN'])
p.set_ylabel('Crashes')
p.set_xlabel('Month')
# Out:
# Text(0.5,0,'Month')

# %%
g = sns.pointplot(x=monthly_crashes.index, y=monthly_crashes['CRASH_CRN'])
g.set_ylabel('Crashes')
g.set_xlabel('Month')
# Out:
# Text(0.5,0,'Month')

# %%
h = sns.stripplot(x=monthly_crashes.index, y=monthly_crashes['CRASH_CRN'], data=monthly_crashes)
h.set_ylabel('Crashes')
h.set_xlabel('Month')
# Out:
# Text(0.5,0,'Month')

# %%
z = sns.lvplot(x=monthly_crashes.index, y=monthly_crashes['CRASH_CRN'], data=monthly_crashes)
z.set_ylabel('Crashes')
z.set_xlabel('Month')
# Out:
# Text(0.5,0,'Month')

# %% [markdown]
# ## 2 Continuous Variables

# %%
fig, ax = plt.subplots(figsize=(20,4))
sns.pointplot(x=crash_data['TIME_OF_DAY'], y=crash_data['AUTOMOBILE_COUNT'], data=crash_data, ax=ax)

# %%
fig, bx = plt.subplots(figsize=(20,4))
sns.swarmplot(x=crash_data['TIME_OF_DAY'], y=crash_data['AUTOMOBILE_COUNT'], data=crash_data, ax=bx)

# %%
fig, cx = plt.subplots(figsize=(20,4))
sns.violinplot(x=crash_data['TIME_OF_DAY'], y=crash_data['AUTOMOBILE_COUNT'], data=crash_data, ax=cx)

# %% [markdown]
# ## 1 Continuous 1 Categorical

# %%
sns.barplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)

# %%
sns.pointplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)

# %%
sns.boxplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)

# %%
sns.lvplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)

# %%
sns.swarmplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)

# %%
sns.violinplot(x=crash_data['HOUR_OF_DAY'], y=crash_data['PERSON_COUNT'], data=crash_data)
